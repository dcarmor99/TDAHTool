# %% [markdown]
# # Importación de librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Carga del dataset

# %%
# --- 2. Cargar el dataset desde Google Drive ---
import os

path = "/content/drive/MyDrive/TFG/DATASETS/NSCH/datos procesados/"

import pandas as pd

file_path = path + "data_processed-vars_2.csv"
df = pd.read_csv(file_path, sep=";")

# %% [markdown]
# # Resumen Dataset

# %%
# Número de filas y columnas
n_filas, n_columnas = df.shape
print(f"Número de filas: {n_filas}")
print(f"Número de columnas: {n_columnas}")

# Rango de edad
if "sc_age_years" in df.columns:
    edad_min = df["sc_age_years"].min()
    edad_max = df["sc_age_years"].max()
    print(f"Rango de edad de los participantes: {edad_min} - {edad_max} años")
else:
    print("La columna 'edad' no se encuentra en el dataset.")

# Diagnóstico de TDAH (número y porcentaje)
if "k2q31a" in df.columns:
    conteo_diagnostico = df["k2q31a"].value_counts()
    porcentaje_diagnostico = df["k2q31a"].value_counts(normalize=True) * 100

    print("\nDistribución de diagnóstico:")
    for valor in conteo_diagnostico.index:
        print(f"{valor}: {conteo_diagnostico[valor]} casos ({porcentaje_diagnostico[valor]:.2f}%)")
else:
    print("La columna 'diagnostico' no se encuentra en el dataset.")
# Out:
# Número de filas: 55162
# Número de columnas: 82
# Rango de edad de los participantes: 0 - 17 años
#
# Distribución de diagnóstico:
# No: 49101 casos (89.01%)
# Yes: 5648 casos (10.24%)
# No valid response: 413 casos (0.75%)

# %% [markdown]
# # División del dataset en train y test

# %%
#Fijar semilla para reproducibilidad
RANDOM_STATE = 42

#Dividimos en 80% train, 20% test
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(df, test_size=0.2, random_state=RANDOM_STATE)

# %% [markdown]
# # Guardado de los datasets

# %%
processed_path_train = '/content/drive/MyDrive/Colab Notebooks/Proyecto-TFG/data/train.csv'
processed_path_test = '/content/drive/MyDrive/Colab Notebooks/Proyecto-TFG/data/test.csv'

# --- 8. Guardar el dataset procesado en Google Drive para el siguiente notebook ---
train_df.to_csv(processed_path_train, index=False)
test_df.to_csv(processed_path_test, index=False)
print(f"✅ Dataset train guardado en: {processed_path_train}")
print(f"✅ Dataset train guardado en: {processed_path_test}")
# Out:
# ✅ Dataset train guardado en: /content/drive/MyDrive/Colab Notebooks/Proyecto-TFG/data/train.csv
# ✅ Dataset train guardado en: /content/drive/MyDrive/Colab Notebooks/Proyecto-TFG/data/test.csv

# %%
# Comprobación de distribución por una variable clave (ej: sexo o edad)
if 'k2q31a' in df.columns:
    print("Distribución por var.objetivo (k2q31a) en original:")
    print(df['k2q31a'].value_counts(normalize=True))
    print(df['k2q31a'].value_counts())
    print()

    print("Distribución por var.objetivo (k2q31a) en train:")
    print(train_df['k2q31a'].value_counts(normalize=True))
    print(train_df['k2q31a'].value_counts())
    print()

    print("Distribución por var.objetivo (k2q31a) en test:")
    print(test_df['k2q31a'].value_counts(normalize=True))
    print(test_df['k2q31a'].value_counts())
    print()
# Out:
# Distribución por var.objetivo (k2q31a) en original:
# k2q31a
# No                   0.890124
# Yes                  0.102389
# No valid response    0.007487
# Name: proportion, dtype: float64
# k2q31a
# No                   49101
# Yes                   5648
# No valid response      413
# Name: count, dtype: int64
#
# Distribución por var.objetivo (k2q31a) en train:
# k2q31a
# No                   0.890435
# Yes                  0.102404
# No valid response    0.007161
# Name: proportion, dtype: float64
# k2q31a
# No                   39294
# Yes                   4519
# No valid response      316
# Name: count, dtype: int64
#
# Distribución por var.objetivo (k2q31a) en test:
# k2q31a
# No                   0.888879
# Yes                  0.102329
# No valid response    0.008792
# Name: proportion, dtype: float64
# k2q31a
# No                   9807
# Yes                  1129
# No valid response      97
# Name: count, dtype: int64

# %%
# 5. Verificaciones básicas del train
print("\nResumen de datos en TRAIN:")
display(train_df.info())
display(train_df.describe(include='all'))
# Out:
# Resumen de datos en TRAIN:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44129 entries, 28031 to 15795
# Data columns (total 82 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   hhlanguage      44129 non-null  object
#  1   sc_age_years    44129 non-null  int64
#  2   sc_sex          44129 non-null  object
#  3   birth_yr        44129 non-null  object
#  4   a1_age          44129 non-null  object
#  5   memorycond      44129 non-null  object
#  6   allergies       44129 non-null  object
#  7   k2q40a          44129 non-null  object
#  8   autoimmune      44129 non-null  object
#  9   headache        44129 non-null  object
#  10  k2q33a          44129 non-null  object
#  11  k2q33b          44129 non-null  object
#  12  k2q32a          44129 non-null  object
#  13  k2q32b          44129 non-null  object
#  14  k2q34a          44129 non-null  object
#  15  k2q34b          44129 non-null  object
#  16  k2q31a          44129 non-null  object
#  17  k2q31b          44129 non-null  object
#  18  k2q31d          44129 non-null  object
#  19  addtreat        44129 non-null  object
#  20  concussion      44129 non-null  object
#  21  confirminjury   44129 non-null  object
#  22  k4q23           44129 non-null  object
#  23  k6q15           44129 non-null  object
#  24  sescurrsvc      44129 non-null  object
#  25  ace9            44129 non-null  object
#  26  cerpals_desc    44129 non-null  object
#  27  cerpals_desc.1  44129 non-null  object
#  28  k2q34c          44129 non-null  object
#  29  k2q31c          44129 non-null  object
#  30  k2q31c.1        44129 non-null  object
#  31  a1_sex          44129 non-null  object
#  32  a1_born         44129 non-null  object
#  33  a1_grade        44129 non-null  object
#  34  a1_marital      43152 non-null  object
#  35  a1_relation     43152 non-null  object
#  36  a1_physhealth   42120 non-null  object
#  37  a1_menthealth   42120 non-null  object
#  38  k6q70_r         42120 non-null  object
#  39  k6q73_r         42120 non-null  object
#  40  k6q71_r         42120 non-null  object
#  41  k7q84_r         42120 non-null  object
#  42  k7q85_r         42120 non-null  object
#  43  k7q82_r         42120 non-null  object
#  44  k7q83_r         42120 non-null  object
#  45  k7q70_r         42120 non-null  object
#  46  bullied_r       42120 non-null  object
#  47  focuson         42120 non-null  object
#  48  nameemotions    42120 non-null  object
#  49  temper_r        42120 non-null  object
#  50  calmdown_r      42120 non-null  object
#  51  waitforturn     42120 non-null  object
#  52  hardwork        42120 non-null  object
#  53  sharetoys       42120 non-null  object
#  54  talkabout       42120 non-null  object
#  55  wktosolve       42120 non-null  object
#  56  k8q31           42120 non-null  object
#  57  k8q32           42120 non-null  object
#  58  k8q34           42120 non-null  object
#  59  k7q04r_r        22982 non-null  object
#  60  outdoorswkday   42120 non-null  object
#  61  outdoorswkend   42120 non-null  object
#  62  screentime      42120 non-null  object
#  63  hcability       42120 non-null  object
#  64  k8q21           42120 non-null  object
#  65  k8q30           42120 non-null  object
#  66  k7q33           42120 non-null  object
#  67  bedtime         42120 non-null  object
#  68  k3q04_r         42120 non-null  object
#  69  makefriend      42120 non-null  object
#  70  grades          42120 non-null  object
#  71  sc_english      42120 non-null  object
#  72  sc_k2q22        42120 non-null  object
#  73  agepos4         42120 non-null  object
#  74  sc_racer        42120 non-null  object
#  75  family_r        42120 non-null  object
#  76  birthwt_l       42120 non-null  object
#  77  birthwt         42120 non-null  object
#  78  birth_yr_f      42120 non-null  object
#  79  higrade         42120 non-null  object
#  80  fpl_i1          42120 non-null  object
#  81  k2q40a.1        44129 non-null  object
# dtypes: int64(1), object(81)
# memory usage: 27.9+ MB
# None
#        hhlanguage  sc_age_years sc_sex birth_yr a1_age memorycond allergies  \
# count       44129  44129.000000  44129    44129  44129      44129     44129
# unique          4           NaN      2       20     54          4         3
# top       English           NaN   Male     2021     38         No        No
# freq        40157           NaN  22629     3682   2113      23178     31286
# mean          NaN      8.341544    NaN      NaN    NaN        NaN       NaN
# std           NaN      5.313594    NaN      NaN    NaN        NaN       NaN
# min           NaN      0.000000    NaN      NaN    NaN        NaN       NaN
# 25%           NaN      4.000000    NaN      NaN    NaN        NaN       NaN
# 50%           NaN      8.000000    NaN      NaN    NaN        NaN       NaN
# 75%           NaN     13.000000    NaN      NaN    NaN        NaN       NaN
# max           NaN     17.000000    NaN      NaN    NaN        NaN       NaN
#
#        k2q40a autoimmune headache  ... sc_k2q22     agepos4     sc_racer  \
# count   44129      44129    44129  ...    42120       42120        42120
# unique      3          3        3  ...        3           5            3
# top        No         No       No  ...       No  Only child  White alone
# freq    39635      43488    42586  ...    36462       16366        32224
# mean      NaN        NaN      NaN  ...      NaN         NaN          NaN
# std       NaN        NaN      NaN  ...      NaN         NaN          NaN
# min       NaN        NaN      NaN  ...      NaN         NaN          NaN
# 25%       NaN        NaN      NaN  ...      NaN         NaN          NaN
# 50%       NaN        NaN      NaN  ...      NaN         NaN          NaN
# 75%       NaN        NaN      NaN  ...      NaN         NaN          NaN
# max       NaN        NaN      NaN  ...      NaN         NaN          NaN
#
#                                                 family_r birthwt_l  \
# count                                              42120     42120
# unique                                                 9         3
# top     Two biogical/adoptive parents, currently married        No
# freq                                               28596     36947
# mean                                                 NaN       NaN
# std                                                  NaN       NaN
# min                                                  NaN       NaN
# 25%                                                  NaN       NaN
# 50%                                                  NaN       NaN
# 75%                                                  NaN       NaN
# max                                                  NaN       NaN
#
#                      birthwt                birth_yr_f                higrade  \
# count                  42120                     42120                  42120
# unique                     4                         4                      3
# top     Not low birth weight  No data quality concerns  More than high school
# freq                   36947                     40400                  37043
# mean                     NaN                       NaN                    NaN
# std                      NaN                       NaN                    NaN
# min                      NaN                       NaN                    NaN
# 25%                      NaN                       NaN                    NaN
# 50%                      NaN                       NaN                    NaN
# 75%                      NaN                       NaN                    NaN
# max                      NaN                       NaN                    NaN
#
#              fpl_i1 k2q40a.1
# count         42120    44129
# unique          350        3
# top     400 or more       No
# freq          18453    39635
# mean            NaN      NaN
# std             NaN      NaN
# min             NaN      NaN
# 25%             NaN      NaN
# 50%             NaN      NaN
# 75%             NaN      NaN
# max             NaN      NaN
#
# [11 rows x 82 columns]
